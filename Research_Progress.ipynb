# %% [markdown]
# <h1><center>Progress Report</center></h1>
# <h2><center>Twitter Dataset</center></h2>
# <center><font color=blue> March 7th, 2018<font></center>
# <center><font color=green> Ahmad Al-Doulat<font></center>

# %% [markdown]
# ## Tweet Structure

# %%
from IPython.core.display import display, HTML
with open('tweetStructure.html', 'r') as f:
    iss_table_html = f.read()
display(HTML(iss_table_html))
# Out:
# <style>
# table, th, td {
#     border: 1px solid black;
# }
# </style>
#
#
# <table class="table">
#
#      <tr>
#        <th align="left">Field</th>
#        <th align="left">Description</th>
#     </tr>
#
#     <tbody><tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>id</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             A unique IRI for the tweet. In more detail, "tag" is the scheme, "search.twitter.com" represents the domain for the scheme, and 2005 is when the scheme was derived.
#                         </p>
#                         <p>
#                             When storing Tweets, this should be used as the unique identifier or primary key.
#                         </p>
#
#                             <p><br>Example:</br> "id": "tag:search.twitter.com,2005:347769243409977344"
#                             </p>
#                     </td>
#
#
#
#     </tr>
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>actor</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             An object representing the twitter user who tweeted.  The Actor Object refers to a Twitter User, and contains all metadata relevant to that user.<br>
#                         </p>
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>verb</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             The type of action being taken by the user.<br>
#                             <br>
#                             Tweets, "post"<br>
#                             Retweets, "share"<br>
#                             Deleted Tweets, "delete"<br>
#                             <br>
#                             The verb is the proper way to distinguish between a Tweet and a true Retweet.  However, this only applies to true retweets, and not modified or quoted Tweets, which don't use Twitter's Retweet functionality.  For a description of AS verbs <a href="http://activitystrea.ms/head/activity-schema.html#verbs">click here</a>.<br>
#                             <br>
#                             For Deletes, note that only a limited number of fields will be included, as shown in the sample payload below.
#                         </p>
#                             <p><br>Example:</br> "verb": "post"
#                             </b>
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>generator</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             An object representing the utility used to post the Tweet. This will contain the name ("displayName") and a link ("link") for the source application generating the Tweet.
#                         </p>
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>provider</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             A JSON object representing the provider of the activity. This will contain an objectType ("service"), the name of the provider ("displayName"), and a link to the provider's website ("link").
#                         </p>
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>inReplyTo</strong></p>
#                     </td>
#                     <td>
#                         <p>
# 				            A JSON object referring to the Tweet being replied to, if applicable. Contains a link to the Tweet.
# 			            </p>
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>location</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             A JSON object representing the Twitter "Place" where the tweet was created. This is an object passed through from the Twitter platform.<br>
#
#                         </p>
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>geo</strong></p>
#                     </td>
#                     <td>
#                         <p>
# 				Point location where the Tweet was created.
# 			</p>
#
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>twitter_entities</strong></p>
#                     </td>
#                     <td>
#                         <p>
# 				The entities object from Twitter's data format which contains lists of urls, mentions and hashtags. Please reference the <a href="https://dev.twitter.com/overview/api/entities">Twitter documentation on Entities here</a>
# 				Note that in Retweets, Twitter may truncate the values of entities that it extracts at the root level. So, for Retweets, your app should look at object.twitter_entities to ensure that you are using non-truncated values.<br>
#
#                         </p>
#                     </td>
#
#
#
#     </tr>
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>twitter_extended_entities</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             An object from Twitter's native data format containing "media". This will be present for any Tweet where the twitter_entities object has data present in the "media" field, and will include multiple photos where present in the post. Note that this is the correct location to retrieve media information for multi-photo posts.<br>
#                             <br>
#                             Multiple photos are represented by comma-separated JSON objects within the "media" array.
#                         </p>
#                     </td>
#
#
#
#     </tr>
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>link</strong></p>
#                     </td>
#                     <td>
#                         <p>
#                             A Permalink for the tweet.
#                         </p>
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>body</strong></p>
#                     </td>
#                     <td>
#                         <p>
# 				The tweet text.<br><br>
#
# 				In Retweets, note that Twitter modifies the value of the body at the root level by adding "RT @username" at the beginning, and by truncating the original text and adding an ellipsis at the end. Thus, for Retweets, your app should look at the object.body to ensure that it is extracting the non-modified text of the original Tweet (being retweeted).
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>
#         <td style="width: 200px">
#                         <p class="accordion-toggle"><strong>objectType</strong></p>
#                     </td>
#                     <td>
#                         <p>
# 				"activity"
# 			</p>
#
#                     </td>
#
#
#
#     </tr>
#
#
#     <tr>

# %% [markdown]
# ## Flattened Dataset

# %%
import pandas as pd

# %%
all_tweets = pd.read_csv('all_tweets.csv', sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
all_tweets
# Out:
#                                                     id objectType   verb  \
# 0       tag:search.twitter.com,2005:947255890691928064   activity   post
# 1       tag:search.twitter.com,2005:947255864913571840   activity   post
# 2       tag:search.twitter.com,2005:947255816553459712   activity   post
# 3       tag:search.twitter.com,2005:947255806659039235   activity   post
# 4       tag:search.twitter.com,2005:947255771217063936   activity  share
# 5       tag:search.twitter.com,2005:947255587867365377   activity  share
# 6       tag:search.twitter.com,2005:947255423194877952   activity   post
# 7       tag:search.twitter.com,2005:947255392953827331   activity   post
# 8       tag:search.twitter.com,2005:947255238200770560   activity   post
# 9       tag:search.twitter.com,2005:947255063327764482   activity   post
# 10      tag:search.twitter.com,2005:947254989520453632   activity   post
# 11      tag:search.twitter.com,2005:947254739783237633   activity   post
# 12      tag:search.twitter.com,2005:947254555602853888   activity   post
# 13      tag:search.twitter.com,2005:947254405224648706   activity  share
# 14      tag:search.twitter.com,2005:947254309745336320   activity   post
# 15      tag:search.twitter.com,2005:947254299070906368   activity   post
# 16      tag:search.twitter.com,2005:947254241994919936   activity   post
# 17      tag:search.twitter.com,2005:947254222629765121   activity   post
# 18      tag:search.twitter.com,2005:947254166249811968   activity   post
# 19      tag:search.twitter.com,2005:947254027363823616   activity   post
# 20      tag:search.twitter.com,2005:947254022842568704   activity   post
# 21      tag:search.twitter.com,2005:947253946464198656   activity   post
# 22      tag:search.twitter.com,2005:947253938088235008   activity   post
# 23      tag:search.twitter.com,2005:947253937253568512   activity   post
# 24      tag:search.twitter.com,2005:947253729346183168   activity   post
# 25      tag:search.twitter.com,2005:947253415364534272   activity   post
# 26      tag:search.twitter.com,2005:947253402639114240   activity  share
# 27      tag:search.twitter.com,2005:947253377838321669   activity   post
# 28      tag:search.twitter.com,2005:947253310326747136   activity   post
# 29      tag:search.twitter.com,2005:947253228948807680   activity   post
# ...                                                ...        ...    ...
# 668334  tag:search.twitter.com,2005:938887292961337345   activity   post
# 668335  tag:search.twitter.com,2005:938887206701273091   activity  share
# 668336  tag:search.twitter.com,2005:938887198866276352   activity   post
# 668337  tag:search.twitter.com,2005:938887193875038209   activity   post
# 668338  tag:search.twitter.com,2005:938887186690269185   activity   post
# 668339  tag:search.twitter.com,2005:938887051138740224   activity   post
# 668340  tag:search.twitter.com,2005:938887046189400064   activity   post
# 668341  tag:search.twitter.com,2005:938886855738646528   activity   post
# 668342  tag:search.twitter.com,2005:938886841272537088   activity   post
# 668343  tag:search.twitter.com,2005:938886713816113153   activity   post
# 668344  tag:search.twitter.com,2005:938886540318658563   activity  share
# 668345  tag:search.twitter.com,2005:938886424627240960   activity   post
# 668346  tag:search.twitter.com,2005:938886136474324992   activity  share
# 668347  tag:search.twitter.com,2005:938886071940734976   activity   post
# 668348  tag:search.twitter.com,2005:938886051858407429   activity  share
# 668349  tag:search.twitter.com,2005:938885880349118465   activity   post
# 668350  tag:search.twitter.com,2005:938885842134884354   activity  share
# 668351  tag:search.twitter.com,2005:938885830558576640   activity   post
# 668352  tag:search.twitter.com,2005:938885730884927488   activity   post
# 668353  tag:search.twitter.com,2005:938885691353829376   activity  share
# 668354  tag:search.twitter.com,2005:938885608885415936   activity  share
# 668355  tag:search.twitter.com,2005:938885573875552256   activity  share
# 668356  tag:search.twitter.com,2005:938885503381843969   activity   post
# 668357  tag:search.twitter.com,2005:938885477167501313   activity  share
# 668358  tag:search.twitter.com,2005:938885367327019008   activity   post
# 668359  tag:search.twitter.com,2005:938885314810036224   activity  share
# 668360  tag:search.twitter.com,2005:938885301082173440   activity   post
# 668361  tag:search.twitter.com,2005:938885298183921665   activity  share
# 668362  tag:search.twitter.com,2005:938885268999897089   activity   post
# 668363  tag:search.twitter.com,2005:938885097205501953   activity  share
#
#                       postedTime  \
# 0       2017-12-30T23:59:38.000Z
# 1       2017-12-30T23:59:32.000Z
# 2       2017-12-30T23:59:20.000Z
# 3       2017-12-30T23:59:18.000Z
# 4       2017-12-30T23:59:09.000Z
# 5       2017-12-30T23:58:25.000Z
# 6       2017-12-30T23:57:46.000Z
# 7       2017-12-30T23:57:39.000Z
# 8       2017-12-30T23:57:02.000Z
# 9       2017-12-30T23:56:20.000Z
# 10      2017-12-30T23:56:03.000Z
# 11      2017-12-30T23:55:03.000Z
# 12      2017-12-30T23:54:19.000Z
# 13      2017-12-30T23:53:43.000Z
# 14      2017-12-30T23:53:21.000Z
# 15      2017-12-30T23:53:18.000Z
# 16      2017-12-30T23:53:05.000Z
# 17      2017-12-30T23:53:00.000Z
# 18      2017-12-30T23:52:47.000Z
# 19      2017-12-30T23:52:13.000Z
# 20      2017-12-30T23:52:12.000Z
# 21      2017-12-30T23:51:54.000Z
# 22      2017-12-30T23:51:52.000Z
# 23      2017-12-30T23:51:52.000Z
# 24      2017-12-30T23:51:02.000Z
# 25      2017-12-30T23:49:47.000Z
# 26      2017-12-30T23:49:44.000Z
# 27      2017-12-30T23:49:39.000Z
# 28      2017-12-30T23:49:22.000Z
# 29      2017-12-30T23:49:03.000Z
# ...                          ...
# 668334  2017-12-07T21:45:48.000Z
# 668335  2017-12-07T21:45:28.000Z
# 668336  2017-12-07T21:45:26.000Z
# 668337  2017-12-07T21:45:25.000Z
# 668338  2017-12-07T21:45:23.000Z
# 668339  2017-12-07T21:44:51.000Z
# 668340  2017-12-07T21:44:50.000Z
# 668341  2017-12-07T21:44:04.000Z
# 668342  2017-12-07T21:44:01.000Z
# 668343  2017-12-07T21:43:30.000Z
# 668344  2017-12-07T21:42:49.000Z
# 668345  2017-12-07T21:42:21.000Z
# 668346  2017-12-07T21:41:13.000Z
# 668347  2017-12-07T21:40:57.000Z
# 668348  2017-12-07T21:40:53.000Z
# 668349  2017-12-07T21:40:12.000Z
# 668350  2017-12-07T21:40:03.000Z
# 668351  2017-12-07T21:40:00.000Z
# 668352  2017-12-07T21:39:36.000Z
# 668353  2017-12-07T21:39:27.000Z
# 668354  2017-12-07T21:39:07.000Z
# 668355  2017-12-07T21:38:59.000Z
# 668356  2017-12-07T21:38:42.000Z
# 668357  2017-12-07T21:38:36.000Z
# 668358  2017-12-07T21:38:09.000Z
# 668359  2017-12-07T21:37:57.000Z
# 668360  2017-12-07T21:37:54.000Z
# 668361  2017-12-07T21:37:53.000Z
# 668362  2017-12-07T21:37:46.000Z
# 668363  2017-12-07T21:37:05.000Z
#
#                                                 generator  \
# 0       {'displayName': 'Twitter for iPhone', 'link': ...
# 1       {'displayName': 'Twitter for iPhone', 'link': ...
# 2       {'displayName': 'punsuimaboka', 'link': 'http:...
# 3       {'displayName': 'penbasameiko', 'link': 'http:...
# 4       {'displayName': 'Twitter for iPhone', 'link': ...
# 5       {'displayName': 'Twitter for iPhone', 'link': ...
# 6       {'displayName': 'Twitter for iPhone', 'link': ...
# 7       {'displayName': 'tafukushiritsuk', 'link': 'ht...
# 8       {'displayName': 'Tweetbot for Mac', 'link': 'h...
# 9       {'displayName': 'Twitter for iPhone', 'link': ...
# 10      {'displayName': 'Twitter for iPhone', 'link': ...
# 11      {'displayName': 'Sprinklr', 'link': 'https://w...
# 12      {'displayName': 'Twitter for iPhone', 'link': ...
# 13      {'displayName': 'Twitter for iPhone', 'link': ...
# 14      {'displayName': 'Gleam Competition App', 'link...
# 15      {'displayName': 'Twitter Web Client', 'link': ...
# 16      {'displayName': 'yushirontezaka', 'link': 'htt...
# 17      {'displayName': 'Twitter for iPhone', 'link': ...
# 18      {'displayName': 'Twitter for iPhone', 'link': ...
# 19      {'displayName': 'Twitter for iPhone', 'link': ...
# 20      {'displayName': 'Twitter for iPhone', 'link': ...
# 21      {'displayName': 'GiveawayPlus', 'link': 'http:...
# 22      {'displayName': 'shikienyatsui', 'link': 'http...
# 23      {'displayName': 'chikuroishioi', 'link': 'http...
# 24      {'displayName': 'Twitter for iPhone', 'link': ...
# 25      {'displayName': 'Twitter Web Client', 'link': ...
# 26      {'displayName': 'Twitter for iPhone', 'link': ...
# 27      {'displayName': 'doroterumaise', 'link': 'http...
# 28      {'displayName': 'dzukeruikakui', 'link': 'http...
# 29      {'displayName': 'Tweetbot for iΟS', 'link': 'h...
# ...                                                   ...
# 668334  {'displayName': 'Twitter for iPhone', 'link': ...
# 668335  {'displayName': 'Twitter Web Client', 'link': ...
# 668336  {'displayName': 'Twitter Web Client', 'link': ...
# 668337  {'displayName': 'Twitter for iPhone', 'link': ...
# 668338  {'displayName': 'WordPress.com', 'link': 'http...
# 668339  {'displayName': 'IFTTT', 'link': 'https://iftt...
# 668340  {'displayName': 'Twitter for iPhone', 'link': ...
# 668341  {'displayName': 'dlvr.it', 'link': 'https://dl...
# 668342  {'displayName': 'Twitter for iPhone', 'link': ...
# 668343  {'displayName': 'Twitter for Android', 'link':...
# 668344  {'displayName': 'Twitter for iPhone', 'link': ...
# 668345  {'displayName': 'IFTTT', 'link': 'https://iftt...
# 668346  {'displayName': 'Twitter for Android', 'link':...
# 668347  {'displayName': 'Twitter for iPhone', 'link': ...
# 668348  {'displayName': 'Twitter for iPhone', 'link': ...
# 668349  {'displayName': 'Twitter for iPhone', 'link': ...
# 668350  {'displayName': 'Twitter for Android', 'link':...
# 668351  {'displayName': 'Buffer', 'link': 'http://buff...
# 668352  {'displayName': 'Twitter for iPhone', 'link': ...
# 668353  {'displayName': 'Twitter for iPhone', 'link': ...
# 668354  {'displayName': 'Twitter for iPhone', 'link': ...
# 668355  {'displayName': 'Twitter for iPhone', 'link': ...
# 668356  {'displayName': 'Twitter Web Client', 'link': ...
# 668357  {'displayName': 'Twitter for iPad', 'link': 'h...
# 668358  {'displayName': 'Twitter Web Client', 'link': ...
# 668359  {'displayName': 'Gleam Competition App', 'link...
# 668360  {'displayName': 'Twitter for iPhone', 'link': ...
# 668361  {'displayName': 'Twitter for iPhone', 'link': ...
# 668362  {'displayName': 'IFTTT', 'link': 'https://iftt...
# 668363  {'displayName': 'SimplySherryltweets', 'link':...
#
#                                                  provider  \
# 0       {'objectType': 'service', 'displayName': 'Twit...
# 1       {'objectType': 'service', 'displayName': 'Twit...
# 2       {'objectType': 'service', 'displayName': 'Twit...
# 3       {'objectType': 'service', 'displayName': 'Twit...
# 4       {'objectType': 'service', 'displayName': 'Twit...
# 5       {'objectType': 'service', 'displayName': 'Twit...
# 6       {'objectType': 'service', 'displayName': 'Twit...
# 7       {'objectType': 'service', 'displayName': 'Twit...
# 8       {'objectType': 'service', 'displayName': 'Twit...
# 9       {'objectType': 'service', 'displayName': 'Twit...
# 10      {'objectType': 'service', 'displayName': 'Twit...
# 11      {'objectType': 'service', 'displayName': 'Twit...
# 12      {'objectType': 'service', 'displayName': 'Twit...
# 13      {'objectType': 'service', 'displayName': 'Twit...
# 14      {'objectType': 'service', 'displayName': 'Twit...
# 15      {'objectType': 'service', 'displayName': 'Twit...
# 16      {'objectType': 'service', 'displayName': 'Twit...
# 17      {'objectType': 'service', 'displayName': 'Twit...
# 18      {'objectType': 'service', 'displayName': 'Twit...
# 19      {'objectType': 'service', 'displayName': 'Twit...
# 20      {'objectType': 'service', 'displayName': 'Twit...
# 21      {'objectType': 'service', 'displayName': 'Twit...
# 22      {'objectType': 'service', 'displayName': 'Twit...
# 23      {'objectType': 'service', 'displayName': 'Twit...
# 24      {'objectType': 'service', 'displayName': 'Twit...
# 25      {'objectType': 'service', 'displayName': 'Twit...
# 26      {'objectType': 'service', 'displayName': 'Twit...
# 27      {'objectType': 'service', 'displayName': 'Twit...
# 28      {'objectType': 'service', 'displayName': 'Twit...
# 29      {'objectType': 'service', 'displayName': 'Twit...
# ...                                                   ...
# 668334  {'objectType': 'service', 'displayName': 'Twit...
# 668335  {'objectType': 'service', 'displayName': 'Twit...
# 668336  {'objectType': 'service', 'displayName': 'Twit...
# 668337  {'objectType': 'service', 'displayName': 'Twit...
# 668338  {'objectType': 'service', 'displayName': 'Twit...
# 668339  {'objectType': 'service', 'displayName': 'Twit...
# 668340  {'objectType': 'service', 'displayName': 'Twit...
# 668341  {'objectType': 'service', 'displayName': 'Twit...
# 668342  {'objectType': 'service', 'displayName': 'Twit...
# 668343  {'objectType': 'service', 'displayName': 'Twit...
# 668344  {'objectType': 'service', 'displayName': 'Twit...
# 668345  {'objectType': 'service', 'displayName': 'Twit...
# 668346  {'objectType': 'service', 'displayName': 'Twit...
# 668347  {'objectType': 'service', 'displayName': 'Twit...
# 668348  {'objectType': 'service', 'displayName': 'Twit...
# 668349  {'objectType': 'service', 'displayName': 'Twit...
# 668350  {'objectType': 'service', 'displayName': 'Twit...
# 668351  {'objectType': 'service', 'displayName': 'Twit...
# 668352  {'objectType': 'service', 'displayName': 'Twit...
# 668353  {'objectType': 'service', 'displayName': 'Twit...
# 668354  {'objectType': 'service', 'displayName': 'Twit...
# 668355  {'objectType': 'service', 'displayName': 'Twit...
# 668356  {'objectType': 'service', 'displayName': 'Twit...
# 668357  {'objectType': 'service', 'displayName': 'Twit...
# 668358  {'objectType': 'service', 'displayName': 'Twit...
# 668359  {'objectType': 'service', 'displayName': 'Twit...
# 668360  {'objectType': 'service', 'displayName': 'Twit...
# 668361  {'objectType': 'service', 'displayName': 'Twit...
# 668362  {'objectType': 'service', 'displayName': 'Twit...
# 668363  {'objectType': 'service', 'displayName': 'Twit...
#
#                                                      link  \
# 0       http://twitter.com/jacobcrowley203/statuses/94...
# 1       http://twitter.com/abrunettesworld/statuses/94...
# 2       http://twitter.com/punsuimaboka/statuses/94725...
# 3       http://twitter.com/penbasameiko/statuses/94725...
# 4       http://twitter.com/DAISYIG18/statuses/94725577...
# 5       http://twitter.com/PMFChristan/statuses/947255...
# 6       http://twitter.com/FLYHowieGee/statuses/947255...
# 7       http://twitter.com/tafukushiritsuk/statuses/94...
# 8       http://twitter.com/bkbkbk/statuses/94725523820...
# 9       http://twitter.com/josequezada_11/statuses/947...
# 10      http://twitter.com/lilbabybiceps/statuses/9472...
# 11      http://twitter.com/SprintWorks4Me/statuses/947...
# 12      http://twitter.com/batfrankk/statuses/94725455...
# 13      http://twitter.com/somerhaldevr/statuses/94725...
# 14      http://twitter.com/swade35b/statuses/947254309...
# 15      http://twitter.com/swade35b/statuses/947254299...
# 16      http://twitter.com/yushirontezaka/statuses/947...
# 17      http://twitter.com/IrishXCI/statuses/947254222...
# 18      http://twitter.com/c_lopez32/statuses/94725416...
# 19      http://twitter.com/cointaaa_/statuses/94725402...
# 20      http://twitter.com/kmilz_z/statuses/9472540228...
# 21      http://twitter.com/Giveaway_Plus/statuses/9472...
# 22      http://twitter.com/shikienyatsui/statuses/9472...
# 23      http://twitter.com/chikuroishioi/statuses/9472...
# 24      http://twitter.com/seanryker10/statuses/947253...
# 25      http://twitter.com/TronDaddyBear/statuses/9472...
# 26      http://twitter.com/TreDayxD/statuses/947253402...
# 27      http://twitter.com/doroterumaise/statuses/9472...
# 28      http://twitter.com/dzukeruikakui/statuses/9472...
# 29      http://twitter.com/Scionwest/statuses/94725322...
# ...                                                   ...
# 668334  http://twitter.com/eugenaruiz555/statuses/9388...
# 668335  http://twitter.com/josephbergdoll/statuses/938...
# 668336  http://twitter.com/HBarr18/statuses/9388871988...
# 668337  http://twitter.com/Kid_Culprit/statuses/938887...
# 668338  http://twitter.com/azemarketing/statuses/93888...
# 668339  http://twitter.com/the_iphone_pro/statuses/938...
# 668340  http://twitter.com/FabianSaidBye_/statuses/938...
# 668341  http://twitter.com/iLounge/statuses/9388868557...
# 668342  http://twitter.com/Servin93/statuses/938886841...
# 668343  http://twitter.com/PieroOrtizCruz1/statuses/93...
# 668344  http://twitter.com/T8_MM8/statuses/93888654031...
# 668345  http://twitter.com/iApplenotice/statuses/93888...
# 668346  http://twitter.com/dolanlawleylove/statuses/93...
# 668347  http://twitter.com/JHarv26/statuses/9388860719...
# 668348  http://twitter.com/JSalata/statuses/9388860518...
# 668349  http://twitter.com/InkPOV/statuses/93888588034...
# 668350  http://twitter.com/johnsondrummer/statuses/938...
# 668351  http://twitter.com/tomcapote/statuses/93888583...
# 668352  http://twitter.com/dexterineffect/statuses/938...
# 668353  http://twitter.com/milkpics/statuses/938885691...
# 668354  http://twitter.com/kem_430/statuses/9388856088...
# 668355  http://twitter.com/kem_430/statuses/9388855738...
# 668356  http://twitter.com/LangeIsaiah/statuses/938885...
# 668357  http://twitter.com/SumocatS/statuses/938885477...
# 668358  http://twitter.com/Darla412/statuses/938885367...
# 668359  http://twitter.com/_procule_/statuses/93888531...
# 668360  http://twitter.com/toft_liam/statuses/93888530...
# 668361  http://twitter.com/AdamCox11/statuses/93888529...
# 668362  http://twitter.com/jlitwinetz/statuses/9388852...
# 668363  http://twitter.com/danavento/statuses/93888509...
#
#                                                      body  \
# 0       Also excited to see if Apple ends up releasing...
# 1       @TheMrsCupcake I’m going to have to go on YouT...
# 2       Taiwanese Publication Spooks Market by Claimin...
# 3       Taiwanese Publication Spooks Market by Claimin...
# 4       RT @matt___nelson: i got the iPhone x here is ...
# 5        RT @JoshTorresFDU: Cracked my iPhone X hell yeah
# 6                             @Melanin_Queen22 iPhone X 🍏
# 7       Galaxy Note 8 crushes iPhone X and Pixel 2 in ...
# 8       @keithurbahn @NYTimesWordplay If only it fit t...
# 9                Bouta get a new phone iPhone 8 or the X?
# 10      @AppleSupport I have the green line of death o...
# 11      @DaltooonG We have a deal you can't resist. Ch...
# 12      @paradeofdreams I NEED, I NEED, I NEED, WHERE?...
# 13      RT @zaralarsson: Sooooo tell my why I can unlo...
# 14      I'm in the running to win an iPhone X from @Sm...
# 15      Help me win this awesome iPhone X from @SmartD...
# 16      Apple suppliers drop on report of weak iPhone ...
# 17                       256GB space grey iPhone X is OP.
# 18      Is it just me or is T-Mobile service atrocious...
# 19      Some bitch really just came up on the iPhone X...
# 20              I’m literally so in love with my iPhone X
# 21      New #AmazonGiveaway 😆📦 (1:n)\n\niPhone X DustP...
# 22      Apple suppliers fall in Asia following report ...
# 23      Apple suppliers fall in Asia following report ...
# 24      iPhone X camera makes Disney even more magical...
# 25      @Apple My iPhone X works great.. so.. yeah.. h...
# 26      RT @DarrellMags: Nah this iPhone X camera the ...
# 27      Wall Street Is Freaking Out Over Possibly Weak...
# 28      Wall Street Is Freaking Out Over Possibly Weak...
# 29      Siri continues to suck. Google Assistant on iP...
# ...                                                   ...
# 668334  I’m trying to tell myself I don’t need that iP...
# 668335  RT @davehariri: Found the artist of the new iP...
# 668336  If you need a gift idea from me: wireless Pika...
# 668337  @UnboxTherapy iPhone X!! #LoveIt https://t.co/...
# 668338  The Apple iPhone X is so 2017; rumors swirl ab...
# 668339  Apple’s Clips app receives a fix for Selfie Sc...
# 668340  I hate this iPhone X bro I keep accidentally s...
# 668341  Gear: Catalyst Impact Protection Case for iPho...
# 668342  Debating if u should get an iPhone X to go alo...
# 668343   @DebRyanShow #Rayito claro como los iphone X!!!!
# 668344  RT @LILBTHEBASEDGOD: Think about it does a sha...
# 668345  Apple’s Clips app receives a fix for Selfie Sc...
# 668346  RT @DavidAlvareeezy: NEW VLOG!\nSo funny guys!...
# 668347  Would love to have the iPhone X with a leather...
# 668348  RT @WDWThemeParks: Epcot's Guardians of the Ga...
# 668349  @Yippieskip AMAZING!!! Well hey, that new iPho...
# 668350  RT @MKBHD: My dream Frankenstein phone from 20...
# 668351  Galaxy S8 and Note 8 are a more sensible buy t...
# 668352                             @UnboxTherapy iPhone X
# 668353  RT @LILBTHEBASEDGOD: Think about it does a sha...
# 668354  RT @GraysonDolan: Just got the iPhone X. Now E...
# 668355  RT @GraysonDolan: This video explains my last ...
# 668356                  @Apple The iPhone X was a mistake
# 668357  RT @benz145: Dear @Apple, I have zero interest...
# 668358  Win a free iPhone X from i-Blason! https://t.c...
# 668359  RT @AoVNPT: With the #AoVNPT coming to a close...
# 668360       Got the iPhone X!!!! https://t.co/fs6F42abTC
# 668361  RT @CryptoBully: You really want to stick it t...
# 668362  #breakingnews #tech\n\nThe Apple iPhone X is s...
# 668363  RT @vaichin: I have been putting the iPhone X ...
#
#                                                     actor  \
# 0       {'objectType': 'person', 'id': 'id:twitter.com...
# 1       {'objectType': 'person', 'id': 'id:twitter.com...
# 2       {'objectType': 'person', 'id': 'id:twitter.com...
# 3       {'objectType': 'person', 'id': 'id:twitter.com...
# 4       {'objectType': 'person', 'id': 'id:twitter.com...
# 5       {'objectType': 'person', 'id': 'id:twitter.com...
# 6       {'objectType': 'person', 'id': 'id:twitter.com...
# 7       {'objectType': 'person', 'id': 'id:twitter.com...
# 8       {'objectType': 'person', 'id': 'id:twitter.com...
# 9       {'objectType': 'person', 'id': 'id:twitter.com...
# 10      {'objectType': 'person', 'id': 'id:twitter.com...
# 11      {'objectType': 'person', 'id': 'id:twitter.com...
# 12      {'objectType': 'person', 'id': 'id:twitter.com...
# 13      {'objectType': 'person', 'id': 'id:twitter.com...
# 14      {'objectType': 'person', 'id': 'id:twitter.com...
# 15      {'objectType': 'person', 'id': 'id:twitter.com...
# 16      {'objectType': 'person', 'id': 'id:twitter.com...
# 17      {'objectType': 'person', 'id': 'id:twitter.com...
# 18      {'objectType': 'person', 'id': 'id:twitter.com...
# 19      {'objectType': 'person', 'id': 'id:twitter.com...
# 20      {'objectType': 'person', 'id': 'id:twitter.com...
# 21      {'objectType': 'person', 'id': 'id:twitter.com...
# 22      {'objectType': 'person', 'id': 'id:twitter.com...
# 23      {'objectType': 'person', 'id': 'id:twitter.com...
# 24      {'objectType': 'person', 'id': 'id:twitter.com...
# 25      {'objectType': 'person', 'id': 'id:twitter.com...
# 26      {'objectType': 'person', 'id': 'id:twitter.com...
# 27      {'objectType': 'person', 'id': 'id:twitter.com...
# 28      {'objectType': 'person', 'id': 'id:twitter.com...
# 29      {'objectType': 'person', 'id': 'id:twitter.com...
# ...                                                   ...
# 668334  {'objectType': 'person', 'id': 'id:twitter.com...
# 668335  {'objectType': 'person', 'id': 'id:twitter.com...
# 668336  {'objectType': 'person', 'id': 'id:twitter.com...
# 668337  {'objectType': 'person', 'id': 'id:twitter.com...
# 668338  {'objectType': 'person', 'id': 'id:twitter.com...
# 668339  {'objectType': 'person', 'id': 'id:twitter.com...
# 668340  {'objectType': 'person', 'id': 'id:twitter.com...
# 668341  {'objectType': 'person', 'id': 'id:twitter.com...
# 668342  {'objectType': 'person', 'id': 'id:twitter.com...
# 668343  {'objectType': 'person', 'id': 'id:twitter.com...
# 668344  {'objectType': 'person', 'id': 'id:twitter.com...
# 668345  {'objectType': 'person', 'id': 'id:twitter.com...
# 668346  {'objectType': 'person', 'id': 'id:twitter.com...
# 668347  {'objectType': 'person', 'id': 'id:twitter.com...
# 668348  {'objectType': 'person', 'id': 'id:twitter.com...
# 668349  {'objectType': 'person', 'id': 'id:twitter.com...
# 668350  {'objectType': 'person', 'id': 'id:twitter.com...
# 668351  {'objectType': 'person', 'id': 'id:twitter.com...
# 668352  {'objectType': 'person', 'id': 'id:twitter.com...
# 668353  {'objectType': 'person', 'id': 'id:twitter.com...
# 668354  {'objectType': 'person', 'id': 'id:twitter.com...
# 668355  {'objectType': 'person', 'id': 'id:twitter.com...
# 668356  {'objectType': 'person', 'id': 'id:twitter.com...
# 668357  {'objectType': 'person', 'id': 'id:twitter.com...
# 668358  {'objectType': 'person', 'id': 'id:twitter.com...
# 668359  {'objectType': 'person', 'id': 'id:twitter.com...
# 668360  {'objectType': 'person', 'id': 'id:twitter.com...
# 668361  {'objectType': 'person', 'id': 'id:twitter.com...
# 668362  {'objectType': 'person', 'id': 'id:twitter.com...
# 668363  {'objectType': 'person', 'id': 'id:twitter.com...
#
#                                                    object favoritesCount  \
# 0       {'objectType': 'note', 'id': 'object:search.tw...              0
# 1       {'objectType': 'note', 'id': 'object:search.tw...              0
# 2       {'objectType': 'note', 'id': 'object:search.tw...              0
# 3       {'objectType': 'note', 'id': 'object:search.tw...              0
# 4       {'id': 'tag:search.twitter.com,2005:9472352979...              0
# 5       {'id': 'tag:search.twitter.com,2005:9470329809...              0
# 6       {'objectType': 'note', 'id': 'object:search.tw...              0
# 7       {'objectType': 'note', 'id': 'object:search.tw...              0
# 8       {'objectType': 'note', 'id': 'object:search.tw...              0
# 9       {'objectType': 'note', 'id': 'object:search.tw...              0
# 10      {'objectType': 'note', 'id': 'object:search.tw...              0
# 11      {'objectType': 'note', 'id': 'object:search.tw...              0
# 12      {'objectType': 'note', 'id': 'object:search.tw...              0
# 13      {'id': 'tag:search.twitter.com,2005:9465809954...              0
# 14      {'objectType': 'note', 'id': 'object:search.tw...              0
# 15      {'objectType': 'note', 'id': 'object:search.tw...              0
# 16      {'objectType': 'note', 'id': 'object:search.tw...              0
# 17      {'objectType': 'note', 'id': 'object:search.tw...              1
# 18      {'objectType': 'note', 'id': 'object:search.tw...              0
# 19      {'objectType': 'note', 'id': 'object:search.tw...              2
# 20      {'objectType': 'note', 'id': 'object:search.tw...              1
# 21      {'objectType': 'note', 'id': 'object:search.tw...              0
# 22      {'objectType': 'note', 'id': 'object:search.tw...              0
# 23      {'objectType': 'note', 'id': 'object:search.tw...              0
# 24      {'objectType': 'note', 'id': 'object:search.tw...         293725
# 25      {'objectType': 'note', 'id': 'object:search.tw...              0
# 26      {'id': 'tag:search.twitter.com,2005:9472516516...              0
# 27      {'objectType': 'note', 'id': 'object:search.tw...              0
# 28      {'objectType': 'note', 'id': 'object:search.tw...              0
# 29      {'objectType': 'note', 'id': 'object:search.tw...              1
# ...                                                   ...            ...
# 668334  {'objectType': 'note', 'id': 'object:search.tw...              7
# 668335  {'id': 'tag:search.twitter.com,2005:9360435626...              0
# 668336  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668337  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668338  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668339  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668340  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668341  {'objectType': 'note', 'id': 'object:search.tw...              3
# 668342  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668343  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668344  {'id': 'tag:search.twitter.com,2005:9386320120...              0
# 668345  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668346  {'id': 'tag:search.twitter.com,2005:9385801428...              0
# 668347  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668348  {'id': 'tag:search.twitter.com,2005:9388812814...              0
# 668349  {'objectType': 'note', 'id': 'object:search.tw...              1
# 668350  {'id': 'tag:search.twitter.com,2005:9362856784...              0
# 668351  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668352  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668353  {'id': 'tag:search.twitter.com,2005:9386320120...              0
# 668354  {'id': 'tag:search.twitter.com,2005:9264845886...              0
# 668355  {'id': 'tag:search.twitter.com,2005:9269125121...              0
# 668356  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668357  {'id': 'tag:search.twitter.com,2005:9387140616...              0
# 668358  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668359  {'id': 'tag:search.twitter.com,2005:9366259568...              0
# 668360  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668361  {'id': 'tag:search.twitter.com,2005:9388047918...              0
# 668362  {'objectType': 'note', 'id': 'object:search.tw...              0
# 668363  {'id': 'tag:search.twitter.com,2005:9382568093...              0
#
#                                          twitter_entities twitter_lang  \
# 0       {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 1       {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 2       {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 3       {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 4       {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 5       {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 6       {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 7       {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 8       {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 9       {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 10      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 11      {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 12      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 13      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 14      {'hashtags': [{'text': 'giveaway', 'indices': ...           en
# 15      {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 16      {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 17      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 18      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 19      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 20      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 21      {'hashtags': [{'text': 'AmazonGiveaway', 'indi...           en
# 22      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 23      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 24      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 25      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 26      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 27      {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 28      {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 29      {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# ...                                                   ...          ...
# 668334  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668335  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668336  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668337  {'hashtags': [{'text': 'LoveIt', 'indices': [2...           en
# 668338  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668339  {'hashtags': [{'text': 'iPhone', 'indices': [8...           en
# 668340  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668341  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668342  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668343  {'hashtags': [{'text': 'Rayito', 'indices': [1...           en
# 668344  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668345  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668346  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668347  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668348  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668349  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668350  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668351  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668352  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668353  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668354  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668355  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668356  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668357  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668358  {'hashtags': [], 'urls': [{'url': 'https://t.c...           en
# 668359  {'hashtags': [{'text': 'AoVNPT', 'indices': [2...           en
# 668360  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668361  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
# 668362  {'hashtags': [{'text': 'breakingnews', 'indice...           en
# 668363  {'hashtags': [], 'urls': [], 'user_mentions': ...           en
#
#        retweetCount                                               gnip  \
# 0                 0                {'matching_rules': [{'tag': None}]}
# 1                 0                {'matching_rules': [{'tag': None}]}
# 2                 0                {'matching_rules': [{'tag': None}]}
# 3                 0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 4               596                {'matching_rules': [{'tag': None}]}
# 5                 1                {'matching_rules': [{'tag': None}]}
# 6                 0                {'matching_rules': [{'tag': None}]}
# 7                 0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 8                 0                {'matching_rules': [{'tag': None}]}
# 9                 0                {'matching_rules': [{'tag': None}]}
# 10                0                {'matching_rules': [{'tag': None}]}
# 11                0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 12                0                {'matching_rules': [{'tag': None}]}
# 13              773                {'matching_rules': [{'tag': None}]}
# 14                0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 15                0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 16                0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 17                0                {'matching_rules': [{'tag': None}]}
# 18                0                {'matching_rules': [{'tag': None}]}
# 19                0                {'matching_rules': [{'tag': None}]}
# 20                0                {'matching_rules': [{'tag': None}]}
# 21                0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 22                0                {'matching_rules': [{'tag': None}]}
# 23                0                {'matching_rules': [{'tag': None}]}
# 24           109683                {'matching_rules': [{'tag': None}]}
# 25                0                {'matching_rules': [{'tag': None}]}
# 26                2                {'matching_rules': [{'tag': None}]}
# 27                0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 28                0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 29                0                {'matching_rules': [{'tag': None}]}
# ...             ...                                                ...
# 668334            1                {'matching_rules': [{'tag': None}]}
# 668335            6  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668336            0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668337            0                {'matching_rules': [{'tag': None}]}
# 668338            0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668339            0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668340            1                {'matching_rules': [{'tag': None}]}
# 668341            1  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668342            0                {'matching_rules': [{'tag': None}]}
# 668343            0                {'matching_rules': [{'tag': None}]}
# 668344         2968                {'matching_rules': [{'tag': None}]}
# 668345            0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668346          167  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668347            0                {'matching_rules': [{'tag': None}]}
# 668348            1                {'matching_rules': [{'tag': None}]}
# 668349            0                {'matching_rules': [{'tag': None}]}
# 668350         6864                {'matching_rules': [{'tag': None}]}
# 668351            0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668352            0                {'matching_rules': [{'tag': None}]}
# 668353         2968                {'matching_rules': [{'tag': None}]}
# 668354        18360                {'matching_rules': [{'tag': None}]}
# 668355        10185  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668356            0                {'matching_rules': [{'tag': None}]}
# 668357            1                {'matching_rules': [{'tag': None}]}
# 668358            0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668359          569  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668360            0                {'matching_rules': [{'tag': None}]}
# 668361         1481                {'matching_rules': [{'tag': None}]}
# 668362            0  {'matching_rules': [{'tag': None}], 'urls': [{...
# 668363           16  {'matching_rules': [{'tag': None}], 'urls': [{...
#
#        twitter_filter_level
# 0                       low
# 1                       low
# 2                       low
# 3                       low
# 4                       low
# 5                       low
# 6                       low
# 7                       low
# 8                       low
# 9                       low
# 10                      low
# 11                      low
# 12                      low
# 13                      low
# 14                      low
# 15                      low
# 16                      low
# 17                      low
# 18                      low
# 19                      low
# 20                      low
# 21                      low
# 22                      low
# 23                      low
# 24                      low
# 25                      low
# 26                      low
# 27                      low
# 28                      low
# 29                      low
# ...                     ...
# 668334                  low
# 668335                  low
# 668336                  low
# 668337                  low
# 668338                  low
# 668339                  low
# 668340                  low
# 668341                  low
# 668342                  low
# 668343                  low
# 668344                  low
# 668345                  low
# 668346                  low
# 668347                  low
# 668348                  low
# 668349                  low
# 668350                  low
# 668351                  low
# 668352                  low
# 668353                  low
# 668354                  low
# 668355                  low
# 668356                  low
# 668357                  low
# 668358                  low
# 668359                  low
# 668360                  low
# 668361                  low
# 668362                  low
# 668363                  low
#
# [668364 rows x 16 columns]

# %%
all_tweets.shape
# Out:
# (668364, 16)

# %% [markdown]
# ### Tweet Fields

# %%
all_tweets.columns
# Out:
# Index(['id', 'objectType', 'verb', 'postedTime', 'generator', 'provider',
#        'link', 'body', 'actor', 'object', 'favoritesCount', 'twitter_entities',
#        'twitter_lang', 'retweetCount', 'gnip', 'twitter_filter_level'],
#       dtype='object')

# %% [markdown]
# ### Number of Tweets

# %%
print('The total number of tweets is: ', all_tweets.shape[0])
# Out:
# The total number of tweets is:  668364

# %% [markdown]
# ### Sample tweet text

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 300
all_tweets.iloc[:30,7:8].style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row0_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row1_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row2_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row3_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row4_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row5_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row6_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row7_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row8_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row9_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row10_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row11_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row12_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row13_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row14_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row15_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row16_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row17_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row18_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row19_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row20_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row21_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row22_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row23_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row24_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row25_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row26_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row27_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row28_col0 {
#             text-align:  left;
#         }    #T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row29_col0 {
#             text-align:  left;
#         }</style>
# <table id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >body</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row0" >0</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row0_col0" class="data row0 col0" >Also excited to see if Apple ends up releasing an iPhone SE 2 with a new 4” screen &amp; A10 chip &amp; wireless charging.… https://t.co/b8w2sP0WRG</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row1" >1</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row1_col0" class="data row1 col0" >@TheMrsCupcake I’m going to have to go on YouTube and watch some iPhone X unboxing/set-up and review how it all wor… https://t.co/yLZs06f8xX</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row2" >2</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row2_col0" class="data row2 col0" >Taiwanese Publication Spooks Market by Claiming Apple has Lowered iPhone X Orders for Q1 2018</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row3" >3</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row3_col0" class="data row3 col0" >Taiwanese Publication Spooks Market by Claiming Apple has Lowered iPhone X Orders for Q1 2018 https://t.co/s82EBBQHDP</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row4" >4</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row4_col0" class="data row4 col0" >RT @matt___nelson: i got the iPhone x here is my dog https://t.co/UiHW7DyJkx</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row5" >5</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row5_col0" class="data row5 col0" >RT @JoshTorresFDU: Cracked my iPhone X hell yeah</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row6" >6</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row6_col0" class="data row6 col0" >@Melanin_Queen22 iPhone X 🍏</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row7" >7</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row7_col0" class="data row7 col0" >Galaxy Note 8 crushes iPhone X and Pixel 2 in OIS video recording comparison https://t.co/rP2f0TcShN</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row8" >8</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row8_col0" class="data row8 col0" >@keithurbahn @NYTimesWordplay If only it fit the screen on iPhone X, or had an iPad keyboard shortcut to toggle bet… https://t.co/L73RhMKZKW</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row9" >9</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row9_col0" class="data row9 col0" >Bouta get a new phone iPhone 8 or the X?</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row10" >10</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row10_col0" class="data row10 col0" >@AppleSupport I have the green line of death on my iPhone X, what do I do?! https://t.co/zy7JDxI1h8</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row11" >11</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row11_col0" class="data row11 col0" >@DaltooonG We have a deal you can't resist. Check our iPhone X with unlimited offer.
# https://t.co/ry6vHY8E0J  ^SJ</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row12" >12</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row12_col0" class="data row12 col0" >@paradeofdreams I NEED, I NEED, I NEED, WHERE? HOW? WHERE? I NEED. DO THEY HAVE IT FOR IPHONE X?!!!!</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row13" >13</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row13_col0" class="data row13 col0" >RT @zaralarsson: Sooooo tell my why I can unlock my sisters iPhone X with my face hahaha we don’t look that alike</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row14" >14</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row14_col0" class="data row14 col0" >I'm in the running to win an iPhone X from @SmartDNSProxy #giveaway #smartdns #vpn https://t.co/84Lvdnjrfu</td>
#     </tr>    <tr>
#         <th id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6" class="row_heading level0 row15" >15</th>
#         <td id="T_8b6ce3d0_222f_11e8_8262_a402b996e2c6row15_col0" class="data row15 col0" >Help me win this awesome iPhone X from @

# %%
cotradicted_pairs = pd.read_csv('Extracted_Contradicted_Tweet_Pairs.csv',encoding='utf-8')

# %%
pd.options.display.max_rows = 200
pd.options.display.max_colwidth = 300
cotradicted_pairs.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row0_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row0_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row0_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row1_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row1_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row1_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row2_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row2_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row2_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row3_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row3_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row3_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row4_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row4_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row4_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row5_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row5_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row5_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row6_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row6_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row6_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row7_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row7_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row7_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row8_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row8_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row8_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row9_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row9_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row9_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row10_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row10_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row10_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row11_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row11_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row11_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row12_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row12_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row12_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row13_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row13_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row13_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row14_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row14_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row14_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row15_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row15_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row15_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row16_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row16_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row16_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row17_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row17_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row17_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row18_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row18_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row18_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row19_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row19_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row19_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row20_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row20_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row20_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row21_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row21_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row21_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row22_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row22_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row22_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row23_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row23_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row23_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row24_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row24_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row24_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row25_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row25_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row25_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row26_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row26_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row26_col2 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row27_col0 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b996e2c6row27_col1 {
#             text-align:  left;
#         }    #T_8cf5d6ae_222f_11e8_b44e_a402b
